# %% [markdown]
# # DS-SF-25 | Codealong 06 | Introduction to Regression and Model Fit

# %%
import os

import numpy as np
import pandas as pd

pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

import statsmodels.api as sm
import statsmodels.formula.api as smf

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

import seaborn as sns

# %%
def read_dataset():
    return pd.read_csv(os.path.join('..', 'datasets', 'zillow-06.csv'), index_col = 'ID')

df = read_dataset()

# %%
df
# Out:
#                                                  Address DateOfSale  \
# ID
# 15063471       55 Vandewater St APT 9, San Francisco, CA    12/4/15
# 15063505             740 Francisco St, San Francisco, CA   11/30/15
# 15063609             819 Francisco St, San Francisco, CA   11/12/15
# 15064044        199 Chestnut St APT 5, San Francisco, CA   12/11/15
# 15064257      111 Chestnut St APT 403, San Francisco, CA    1/15/16
# 15064295      111 Chestnut St APT 702, San Francisco, CA   12/17/15
# 15064391       1821 Grant Ave APT 101, San Francisco, CA   12/15/15
# 15064536          2300 Leavenworth St, San Francisco, CA    12/4/15
# 15064640         1047-1049 Lombard St, San Francisco, CA    1/14/16
# 15064669          1055 Lombard St # C, San Francisco, CA   12/31/15
# 15065032      101 Lombard St APT 116E, San Francisco, CA    12/7/15
# 15065140     1407 Montgomery St APT 2, San Francisco, CA    1/28/16
# 15065727     1360 Montgomery St APT 1, San Francisco, CA   11/16/15
# 15065810          1327-1329 Kearny St, San Francisco, CA   11/25/15
# 15065946       44 Macondray Ln APT 2E, San Francisco, CA   11/30/15
# 15066001        1070 Green St APT 201, San Francisco, CA   11/18/15
# 15066036       1070 Green St APT 1402, San Francisco, CA   12/31/15
# 15066085    1907 Leavenworth St APT 8, San Francisco, CA   11/12/15
# 15066201          1101 Green St # 303, San Francisco, CA   11/16/15
# 15066281                1807 Jones St, San Francisco, CA   12/15/15
# 15066344         999 Green St APT 905, San Francisco, CA   12/10/15
# 15066608       455 Vallejo St APT 111, San Francisco, CA   12/16/15
# 15066839         1163-1165 Vallejo St, San Francisco, CA    12/1/15
# 15066959             1300 Pacific Ave, San Francisco, CA    1/14/16
# 15067302               948 Jackson St, San Francisco, CA   11/13/15
# 15067583       946 Stockton St APT 6B, San Francisco, CA   12/18/15
# 15067604       946 Stockton St APT 9E, San Francisco, CA    12/2/15
# 15067755         1250 Clay St APT 306, San Francisco, CA    1/10/16
# 15067890        1250 Jones St APT 503, San Francisco, CA    12/4/15
# 15067896        1250 Jones St APT 802, San Francisco, CA   12/15/15
# ...                                                  ...        ...
# 2100992607               2137 Pine St, San Francisco, CA    1/15/16
# 2100994004              409 Miguel St, San Francisco, CA    12/9/15
# 2101028916            251 Missouri St, San Francisco, CA   12/17/15
# 2101094207            1650 Florida St, San Francisco, CA   11/29/15
# 2101105851          41 Collingwood St, San Francisco, CA   12/10/15
# 2101116542             2753 Bryant St, San Francisco, CA    1/14/16
# 2101147349            244 Precita Ave, San Francisco, CA   11/26/15
# 2101153805                6 Rossi Ave, San Francisco, CA    12/2/15
# 2101156735            333 Potrero Ave, San Francisco, CA     1/5/16
# 2101167573              1340 Union St, San Francisco, CA    1/25/16
# 2101169168            688 Douglass St, San Francisco, CA   11/10/15
# 2101175813              414 Linden St, San Francisco, CA   12/13/15
# 2101331127      1408 31st Ave APT 303, San Francisco, CA   12/28/15
# 2101505254               333 Beale St, San Francisco, CA    12/3/15
# 2101588805             82 Alvarado St, San Francisco, CA   11/19/15
# 2101807538         2619 Sacramento St, San Francisco, CA    12/2/15
# 2102385068            129 Central Ave, San Francisco, CA    12/1/15
# 2102906272              444 Linden St, San Francisco, CA   12/14/15
# 2106229715              2595 38th Ave, San Francisco, CA    1/19/16
# 2108411930               3500 19th St, San Francisco, CA   12/29/15
# 2108546010      1738 Lombard St APT 4, San Francisco, CA    1/14/16
# 2114498518    201 Sansome St UNIT 501, San Francisco, CA    1/26/16
# 2121221385              925 Larkin St, San Francisco, CA   11/30/15
# 2121978635     829 Folsom St UNIT 906, San Francisco, CA    12/6/15
# 2122992200             129 Octavia St, San Francisco, CA   11/20/15
# 2124214951         412 Green St APT A, San Francisco, CA    1/15/16
# 2126960082       355 1st St UNIT 1905, San Francisco, CA   11/20/15
# 2128308939          33 Santa Cruz Ave, San Francisco, CA   12/10/15
# 2131957929             1821 Grant Ave, San Francisco, CA   12/15/15
# 2136213970              1200 Gough St, San Francisco, CA    1/10/16
#
#             SalePrice  IsAStudio  BedCount  BathCount    Size  LotSize  \
# ID
# 15063471     710000.0        0.0       1.0        NaN   550.0      NaN
# 15063505    2150000.0        0.0       NaN        2.0  1430.0   2435.0
# 15063609    5600000.0        0.0       2.0        3.5  2040.0   3920.0
# 15064044    1500000.0        0.0       1.0        1.0  1060.0      NaN
# 15064257     970000.0        0.0       2.0        2.0  1299.0      NaN
# 15064295     940000.0        0.0       2.0        2.0  1033.0      NaN
# 15064391     835000.0        0.0       1.0        1.0  1048.0      NaN
# 15064536    2830000.0        0.0       3.0        2.0  2115.0   1271.0
# 15064640    4050000.0        1.0       NaN        NaN  4102.0   3049.0
# 15064669    2190000.0        0.0       2.0        3.0  1182.0      NaN
# 15065032     800000.0        0.0       1.0        1.0  1000.0      NaN
# 15065140     976000.0        0.0       1.0        1.0  1000.0      NaN
# 15065727     720000.0        0.0       1.0        1.0   552.0      NaN
# 15065810    2250000.0        0.0       NaN        4.0  2658.0   1600.0
# 15065946    1290000.0        0.0       2.0        2.0  1165.0      NaN
# 15066001    2900000.0        0.0       2.0        2.0  1465.0      NaN
# 15066036    2600000.0        0.0       3.0        2.5  2017.0      NaN
# 15066085     908000.0        0.0       2.0        1.0   956.0      NaN
# 15066201    1210000.0        0.0       2.0        1.0  1003.0      NaN
# 15066281    1700000.0        0.0       2.0        2.0  1467.0   3023.0
# 15066344    1280000.0        0.0       1.0        1.0   986.0      NaN
# 15066608     875000.0        0.0       1.0        1.0   825.0      NaN
# 15066839     300000.0        0.0       NaN        2.0  2344.0   1376.0
# 15066959     425000.0        1.0       NaN        2.0   989.0      NaN
# 15067302    1950000.0        0.0       NaN        4.0  4362.0   1459.0
# 15067583     775000.0        0.0       NaN        2.0   710.0      NaN
# 15067604     705000.0        0.0       2.0        2.0   744.0      NaN
# 15067755     695000.0        0.0       1.0        1.0   541.0      NaN
# 15067890    1410000.0        0.0       1.0        1.0  1250.0      NaN
# 15067896    1680000.0        0.0       1.0        1.0  1115.0      NaN
# ...               ...        ...       ...        ...     ...      ...
# 2100992607  1550000.0        0.0       4.0        2.5  1632.0      NaN
# 2100994004   510000.0        0.0       1.0        1.0   400.0      NaN
# 2101028916  2450000.0        0.0       4.0        3.0  2301.0      NaN
# 2101094207   970000.0        0.0       3.0        1.0     NaN      NaN
# 2101105851  1300000.0        0.0       3.0        1.0  1496.0      NaN
# 2101116542  1700000.0        0.0       9.0        3.0  4005.0      NaN
# 2101147349   785000.0        0.0       1.0        1.0   625.0      NaN
# 2101153805  1150000.0        0.0       3.0        1.0  1912.0      NaN
# 2101156735  1140000.0        1.0       NaN        NaN  1776.0   3746.0
# 2101167573  1250000.0        0.0       2.0        2.0  1108.0      NaN
# 2101169168  3150000.0        1.0       NaN        NaN  3500.0   2495.0
# 2101175813   835000.0        0.0       1.0        1.0     NaN      NaN
# 2101331127   890000.0        0.0       2.0        2.0  1424.0      NaN
# 2101505254  1400000.0        0.0       1.0        1.0   950.0      NaN
# 2101588805   750000.0        0.0       2.0        1.0     NaN      NaN
# 2101807538  2900000.0        1.0       NaN        NaN     NaN   2038.0
# 2102385068  1800000.0        0.0       3.0        2.0     NaN      NaN
# 2102906272     5800.0        NaN       NaN        NaN     NaN      NaN
# 2106229715  1240000.0        0.0       3.0        3.0  2414.0   1306.0
# 2108411930  1730000.0        0.0       2.0        2.5  1500.0      NaN
# 2108546010  1400000.0        0.0       2.0        2.0     NaN      NaN
# 2114498518   757500.0        0.0       1.0        1.0   658.0      NaN
# 2121221385  1430000.0        0.0       NaN        NaN  6600.0      NaN
# 2121978635   675000.0        0.0       1.0        1.0   557.0      NaN
# 2122992200  2750000.0        1.0       NaN        NaN  3655.0      NaN
# 2124214951   390000.0        1.0       NaN        1.0   264.0      NaN
# 2126960082   860000.0        0.0       1.0        1.0   691.0      NaN
# 2128308939   830000.0        0.0       3.0        3.0  1738.0   2299.0
# 2131957929   835000.0        0.0       2.0        2.0  1048.0      NaN
# 2136213970   825000.0        0.0       1.0        1.0   900.0      NaN
#
#             BuiltInYear
# ID
# 15063471         1980.0
# 15063505         1948.0
# 15063609         1976.0
# 15064044         1930.0
# 15064257         1993.0
# 15064295         1993.0
# 15064391         1975.0
# 15064536         1913.0
# 15064640         1948.0
# 15064669         1986.0
# 15065032         1983.0
# 15065140         1870.0
# 15065727         1937.0
# 15065810         1906.0
# 15065946         1980.0
# 15066001         1963.0
# 15066036         1963.0
# 15066085         1907.0
# 15066201         1930.0
# 15066281         1922.0
# 15066344         1964.0
# 15066608         1973.0
# 15066839         1913.0
# 15066959         1910.0
# 15067302         1908.0
# 15067583         1970.0
# 15067604         1970.0
# 15067755         1950.0
# 15067890         1929.0
# 15067896         1929.0
# ...                 ...
# 2100992607          NaN
# 2100994004          NaN
# 2101028916       1900.0
# 2101094207       1904.0
# 2101105851       1908.0
# 2101116542       1900.0
# 2101147349       1908.0
# 2101153805       1941.0
# 2101156735       1905.0
# 2101167573       1951.0
# 2101169168       1908.0
# 2101175813       1909.0
# 2101331127       2008.0
# 2101505254       2015.0
# 2101588805          NaN
# 2101807538       1900.0
# 2102385068       1905.0
# 2102906272          NaN
# 2106229715       1943.0
# 2108411930       2013.0
# 2108546010       2004.0
# 2114498518       1909.0
# 2121221385       1907.0
# 2121978635       2010.0
# 2122992200       1883.0
# 2124214951       2012.0
# 2126960082       2004.0
# 2128308939       1976.0
# 2131957929       1975.0
# 2136213970       1966.0
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## Part A1 - Simple Linear Regression

# %% [markdown]
# ### Transforming Variables, e.g., scaling

# %% [markdown]
# > #### Activity | How to scale SalePrice from \$ to \$M, Size and LotSize from sqft to "1,000 sqft"?

# %%
def scale_variables(df):
    # TODO: Sale price in $M
    # TODO: Size in 1,000 sqft
    # TODO: Lot size in 1,000 sqft

scale_variables(df)

# %%
df
# Out:
#                                                  Address DateOfSale  \
# ID
# 15063471       55 Vandewater St APT 9, San Francisco, CA    12/4/15
# 15063505             740 Francisco St, San Francisco, CA   11/30/15
# 15063609             819 Francisco St, San Francisco, CA   11/12/15
# 15064044        199 Chestnut St APT 5, San Francisco, CA   12/11/15
# 15064257      111 Chestnut St APT 403, San Francisco, CA    1/15/16
# 15064295      111 Chestnut St APT 702, San Francisco, CA   12/17/15
# 15064391       1821 Grant Ave APT 101, San Francisco, CA   12/15/15
# 15064536          2300 Leavenworth St, San Francisco, CA    12/4/15
# 15064640         1047-1049 Lombard St, San Francisco, CA    1/14/16
# 15064669          1055 Lombard St # C, San Francisco, CA   12/31/15
# 15065032      101 Lombard St APT 116E, San Francisco, CA    12/7/15
# 15065140     1407 Montgomery St APT 2, San Francisco, CA    1/28/16
# 15065727     1360 Montgomery St APT 1, San Francisco, CA   11/16/15
# 15065810          1327-1329 Kearny St, San Francisco, CA   11/25/15
# 15065946       44 Macondray Ln APT 2E, San Francisco, CA   11/30/15
# 15066001        1070 Green St APT 201, San Francisco, CA   11/18/15
# 15066036       1070 Green St APT 1402, San Francisco, CA   12/31/15
# 15066085    1907 Leavenworth St APT 8, San Francisco, CA   11/12/15
# 15066201          1101 Green St # 303, San Francisco, CA   11/16/15
# 15066281                1807 Jones St, San Francisco, CA   12/15/15
# 15066344         999 Green St APT 905, San Francisco, CA   12/10/15
# 15066608       455 Vallejo St APT 111, San Francisco, CA   12/16/15
# 15066839         1163-1165 Vallejo St, San Francisco, CA    12/1/15
# 15066959             1300 Pacific Ave, San Francisco, CA    1/14/16
# 15067302               948 Jackson St, San Francisco, CA   11/13/15
# 15067583       946 Stockton St APT 6B, San Francisco, CA   12/18/15
# 15067604       946 Stockton St APT 9E, San Francisco, CA    12/2/15
# 15067755         1250 Clay St APT 306, San Francisco, CA    1/10/16
# 15067890        1250 Jones St APT 503, San Francisco, CA    12/4/15
# 15067896        1250 Jones St APT 802, San Francisco, CA   12/15/15
# ...                                                  ...        ...
# 2100992607               2137 Pine St, San Francisco, CA    1/15/16
# 2100994004              409 Miguel St, San Francisco, CA    12/9/15
# 2101028916            251 Missouri St, San Francisco, CA   12/17/15
# 2101094207            1650 Florida St, San Francisco, CA   11/29/15
# 2101105851          41 Collingwood St, San Francisco, CA   12/10/15
# 2101116542             2753 Bryant St, San Francisco, CA    1/14/16
# 2101147349            244 Precita Ave, San Francisco, CA   11/26/15
# 2101153805                6 Rossi Ave, San Francisco, CA    12/2/15
# 2101156735            333 Potrero Ave, San Francisco, CA     1/5/16
# 2101167573              1340 Union St, San Francisco, CA    1/25/16
# 2101169168            688 Douglass St, San Francisco, CA   11/10/15
# 2101175813              414 Linden St, San Francisco, CA   12/13/15
# 2101331127      1408 31st Ave APT 303, San Francisco, CA   12/28/15
# 2101505254               333 Beale St, San Francisco, CA    12/3/15
# 2101588805             82 Alvarado St, San Francisco, CA   11/19/15
# 2101807538         2619 Sacramento St, San Francisco, CA    12/2/15
# 2102385068            129 Central Ave, San Francisco, CA    12/1/15
# 2102906272              444 Linden St, San Francisco, CA   12/14/15
# 2106229715              2595 38th Ave, San Francisco, CA    1/19/16
# 2108411930               3500 19th St, San Francisco, CA   12/29/15
# 2108546010      1738 Lombard St APT 4, San Francisco, CA    1/14/16
# 2114498518    201 Sansome St UNIT 501, San Francisco, CA    1/26/16
# 2121221385              925 Larkin St, San Francisco, CA   11/30/15
# 2121978635     829 Folsom St UNIT 906, San Francisco, CA    12/6/15
# 2122992200             129 Octavia St, San Francisco, CA   11/20/15
# 2124214951         412 Green St APT A, San Francisco, CA    1/15/16
# 2126960082       355 1st St UNIT 1905, San Francisco, CA   11/20/15
# 2128308939          33 Santa Cruz Ave, San Francisco, CA   12/10/15
# 2131957929             1821 Grant Ave, San Francisco, CA   12/15/15
# 2136213970              1200 Gough St, San Francisco, CA    1/10/16
#
#             SalePrice  IsAStudio  BedCount  BathCount   Size  LotSize  \
# ID
# 15063471       0.7100        0.0       1.0        NaN  0.550      NaN
# 15063505       2.1500        0.0       NaN        2.0  1.430    2.435
# 15063609       5.6000        0.0       2.0        3.5  2.040    3.920
# 15064044       1.5000        0.0       1.0        1.0  1.060      NaN
# 15064257       0.9700        0.0       2.0        2.0  1.299      NaN
# 15064295       0.9400        0.0       2.0        2.0  1.033      NaN
# 15064391       0.8350        0.0       1.0        1.0  1.048      NaN
# 15064536       2.8300        0.0       3.0        2.0  2.115    1.271
# 15064640       4.0500        1.0       NaN        NaN  4.102    3.049
# 15064669       2.1900        0.0       2.0        3.0  1.182      NaN
# 15065032       0.8000        0.0       1.0        1.0  1.000      NaN
# 15065140       0.9760        0.0       1.0        1.0  1.000      NaN
# 15065727       0.7200        0.0       1.0        1.0  0.552      NaN
# 15065810       2.2500        0.0       NaN        4.0  2.658    1.600
# 15065946       1.2900        0.0       2.0        2.0  1.165      NaN
# 15066001       2.9000        0.0       2.0        2.0  1.465      NaN
# 15066036       2.6000        0.0       3.0        2.5  2.017      NaN
# 15066085       0.9080        0.0       2.0        1.0  0.956      NaN
# 15066201       1.2100        0.0       2.0        1.0  1.003      NaN
# 15066281       1.7000        0.0       2.0        2.0  1.467    3.023
# 15066344       1.2800        0.0       1.0        1.0  0.986      NaN
# 15066608       0.8750        0.0       1.0        1.0  0.825      NaN
# 15066839       0.3000        0.0       NaN        2.0  2.344    1.376
# 15066959       0.4250        1.0       NaN        2.0  0.989      NaN
# 15067302       1.9500        0.0       NaN        4.0  4.362    1.459
# 15067583       0.7750        0.0       NaN        2.0  0.710      NaN
# 15067604       0.7050        0.0       2.0        2.0  0.744      NaN
# 15067755       0.6950        0.0       1.0        1.0  0.541      NaN
# 15067890       1.4100        0.0       1.0        1.0  1.250      NaN
# 15067896       1.6800        0.0       1.0        1.0  1.115      NaN
# ...               ...        ...       ...        ...    ...      ...
# 2100992607     1.5500        0.0       4.0        2.5  1.632      NaN
# 2100994004     0.5100        0.0       1.0        1.0  0.400      NaN
# 2101028916     2.4500        0.0       4.0        3.0  2.301      NaN
# 2101094207     0.9700        0.0       3.0        1.0    NaN      NaN
# 2101105851     1.3000        0.0       3.0        1.0  1.496      NaN
# 2101116542     1.7000        0.0       9.0        3.0  4.005      NaN
# 2101147349     0.7850        0.0       1.0        1.0  0.625      NaN
# 2101153805     1.1500        0.0       3.0        1.0  1.912      NaN
# 2101156735     1.1400        1.0       NaN        NaN  1.776    3.746
# 2101167573     1.2500        0.0       2.0        2.0  1.108      NaN
# 2101169168     3.1500        1.0       NaN        NaN  3.500    2.495
# 2101175813     0.8350        0.0       1.0        1.0    NaN      NaN
# 2101331127     0.8900        0.0       2.0        2.0  1.424      NaN
# 2101505254     1.4000        0.0       1.0        1.0  0.950      NaN
# 2101588805     0.7500        0.0       2.0        1.0    NaN      NaN
# 2101807538     2.9000        1.0       NaN        NaN    NaN    2.038
# 2102385068     1.8000        0.0       3.0        2.0    NaN      NaN
# 2102906272     0.0058        NaN       NaN        NaN    NaN      NaN
# 2106229715     1.2400        0.0       3.0        3.0  2.414    1.306
# 2108411930     1.7300        0.0       2.0        2.5  1.500      NaN
# 2108546010     1.4000        0.0       2.0        2.0    NaN      NaN
# 2114498518     0.7575        0.0       1.0        1.0  0.658      NaN
# 2121221385     1.4300        0.0       NaN        NaN  6.600      NaN
# 2121978635     0.6750        0.0       1.0        1.0  0.557      NaN
# 2122992200     2.7500        1.0       NaN        NaN  3.655      NaN
# 2124214951     0.3900        1.0       NaN        1.0  0.264      NaN
# 2126960082     0.8600        0.0       1.0        1.0  0.691      NaN
# 2128308939     0.8300        0.0       3.0        3.0  1.738    2.299
# 2131957929     0.8350        0.0       2.0        2.0  1.048      NaN
# 2136213970     0.8250        0.0       1.0        1.0  0.900      NaN
#
#             BuiltInYear
# ID
# 15063471         1980.0
# 15063505         1948.0
# 15063609         1976.0
# 15064044         1930.0
# 15064257         1993.0
# 15064295         1993.0
# 15064391         1975.0
# 15064536         1913.0
# 15064640         1948.0
# 15064669         1986.0
# 15065032         1983.0
# 15065140         1870.0
# 15065727         1937.0
# 15065810         1906.0
# 15065946         1980.0
# 15066001         1963.0
# 15066036         1963.0
# 15066085         1907.0
# 15066201         1930.0
# 15066281         1922.0
# 15066344         1964.0
# 15066608         1973.0
# 15066839         1913.0
# 15066959         1910.0
# 15067302         1908.0
# 15067583         1970.0
# 15067604         1970.0
# 15067755         1950.0
# 15067890         1929.0
# 15067896         1929.0
# ...                 ...
# 2100992607          NaN
# 2100994004          NaN
# 2101028916       1900.0
# 2101094207       1904.0
# 2101105851       1908.0
# 2101116542       1900.0
# 2101147349       1908.0
# 2101153805       1941.0
# 2101156735       1905.0
# 2101167573       1951.0
# 2101169168       1908.0
# 2101175813       1909.0
# 2101331127       2008.0
# 2101505254       2015.0
# 2101588805          NaN
# 2101807538       1900.0
# 2102385068       1905.0
# 2102906272          NaN
# 2106229715       1943.0
# 2108411930       2013.0
# 2108546010       2004.0
# 2114498518       1909.0
# 2121221385       1907.0
# 2121978635       2010.0
# 2122992200       1883.0
# 2124214951       2012.0
# 2126960082       2004.0
# 2128308939       1976.0
# 2131957929       1975.0
# 2136213970       1966.0
#
# [1000 rows x 9 columns]

# %% [markdown]
# ### `SalePrice` as a function of `Size`

# %%
def Xy(df):
    # TODO

    return X, y

X, y = Xy(df)

model = smf.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Mon, 01 Aug 2016   Prob (F-statistic):                nan
# Time:                        19:25:33   Log-Likelihood:                    nan
# No. Observations:                1000   AIC:                               nan
# Df Residuals:                    1000   BIC:                               nan
# Df Model:                          -1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Size              nan        nan        nan        nan           nan       nan
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                          nan
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### `SalePrice` as a function of `Size` - Take 2

# %%
def Xy(df):
    # TODO: X
    # TODO: y

    return X, y

X, y = Xy(df)

model = smf.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.565
# Method:                 Least Squares   F-statistic:                     1255.
# Date:                Mon, 01 Aug 2016   Prob (F-statistic):          7.83e-177
# Time:                        19:26:46   Log-Likelihood:                -1689.6
# No. Observations:                 967   AIC:                             3381.
# Df Residuals:                     966   BIC:                             3386.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Size           0.8176      0.023     35.426      0.000         0.772     0.863
# ==============================================================================
# Omnibus:                     1830.896   Durbin-Watson:                   1.722
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3370566.094
# Skew:                          13.300   Prob(JB):                         0.00
# Kurtosis:                     291.005   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Making predictions

# %%
predict_X = pd.DataFrame({'Size': [1.2, 1.4, 1.6]})

# %%
predict_X
# Out:
#    Size
# 0   1.2
# 1   1.4
# 2   1.6

# %%
predict_y = model.predict(predict_X)

# %%
predict_y
# Out:
# array([ 0.98116288,  1.14469003,  1.30821717])

# %%
type(predict_y)
# Out:
# numpy.ndarray

# %% [markdown]
# ### `SalePrice` as a function of `Size` - Take 3

# %%
def Xy(df):
    # TODO: X
    # TODO: y

    return X, y

X, y = Xy(df)

model = smf.OLS(y, X).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     297.4
# Date:                Mon, 01 Aug 2016   Prob (F-statistic):           2.67e-58
# Time:                        19:31:04   Log-Likelihood:                -1687.9
# No. Observations:                 967   AIC:                             3380.
# Df Residuals:                     965   BIC:                             3390.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# const          0.1551      0.084      1.842      0.066        -0.010     0.320
# Size           0.7497      0.043     17.246      0.000         0.664     0.835
# ==============================================================================
# Omnibus:                     1842.865   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3398350.943
# Skew:                          13.502   Prob(JB):                         0.00
# Kurtosis:                     292.162   Cond. No.                         4.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Making predicitions (cont.)

# %%
predict_X = pd.DataFrame({'Size': [1.2, 1.4, 1.6]})
predict_X = sm.add_constant(predict_X)

# %%
predict_X
# Out:
#    const  Size
# 0      1   1.2
# 1      1   1.4
# 2      1   1.6

# %%
predict_y = model.predict(predict_X)

# %%
predict_y
# Out:
# array([ 1.05472548,  1.2046711 ,  1.35461672])

# %% [markdown]
# ### Model's parameters

# %%
model.params
# Out:
# const    0.155052
# Size     0.749728
# dtype: float64

# %%
type(model.params)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### t-values

# %%
model.tvalues
# Out:
# const     1.842394
# Size     17.245775
# dtype: float64

# %% [markdown]
# ### p-values

# %%
model.pvalues
# Out:
# const    6.572416e-02
# Size     2.667697e-58
# dtype: float64

# %% [markdown]
# ### Confidence Intervals

# %%
model.conf_int()
# Out:
#               0         1
# const -0.010102  0.320205
# Size   0.664415  0.835041

# %%
model.conf_int(alpha = 0.05).rename(columns= {0: '2.5%', 1: '97.5%' })
# Out:
#            2.5%     97.5%
# const -0.010102  0.320205
# Size   0.664415  0.835041

# %%
model.conf_int(alpha = 0.10).rename(columns= {0: '5%', 1: '95%' }) # FORCE constant's significance (increase confidence interval)
# Out:
#              5%       95%
# const  0.016492  0.293612
# Size   0.678152  0.821304

# %% [markdown]
# ## Part A2 - Simple Linear Regression (cont.)

# %% [markdown]
# #### Alternatively | Using a "formula"

# %%
model = smf.ols(formula = "SalePrice ~ Size", data = df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     297.4
# Date:                Mon, 01 Aug 2016   Prob (F-statistic):           2.67e-58
# Time:                        19:47:43   Log-Likelihood:                -1687.9
# No. Observations:                 967   AIC:                             3380.
# Df Residuals:                     965   BIC:                             3390.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.1551      0.084      1.842      0.066        -0.010     0.320
# Size           0.7497      0.043     17.246      0.000         0.664     0.835
# ==============================================================================
# Omnibus:                     1842.865   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3398350.943
# Skew:                          13.502   Prob(JB):                         0.00
# Kurtosis:                     292.162   Cond. No.                         4.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### `SalePrice` as a function of `Size` without `Intercept`

# %%
model = smf.ols(formula = 'SalePrice ~ 0 + Size', data = df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.565
# Model:                            OLS   Adj. R-squared:                  0.565
# Method:                 Least Squares   F-statistic:                     1255.
# Date:                Mon, 01 Aug 2016   Prob (F-statistic):          7.83e-177
# Time:                        19:48:53   Log-Likelihood:                -1689.6
# No. Observations:                 967   AIC:                             3381.
# Df Residuals:                     966   BIC:                             3386.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Size           0.8176      0.023     35.426      0.000         0.772     0.863
# ==============================================================================
# Omnibus:                     1830.896   Durbin-Watson:                   1.722
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3370566.094
# Skew:                          13.300   Prob(JB):                         0.00
# Kurtosis:                     291.005   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### Drop outliers

# %%
def drop_outliers(df):
    print 'Dropping outliers'
    print '- n (before) =', df.shape[0]

    # TODO

    print '- Q1         =', Q1, '($M)'
    print '- Q2/Median  =', Q2, '($M)'
    print '- Q3         =', Q3, '($M)'

    # TODO

    print '- n (after)  =', df.shape[0]

drop_outliers(df)
# Out:
# Dropping outliers
# - n (before) = 1000
# - Q1         = 0.8 ($M)
# - Q2/Median  = 1.1 ($M)
# - Q3         = 1.5325 ($M)
# - n (after)  = 933

# %% [markdown]
# ### `SalePrice` as a function of `Size` (again)

# %%
model = smf.ols(formula = 'SalePrice ~ Size', data = df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.200
# Model:                            OLS   Adj. R-squared:                  0.199
# Method:                 Least Squares   F-statistic:                     225.0
# Date:                Mon, 01 Aug 2016   Prob (F-statistic):           1.41e-45
# Time:                        20:19:31   Log-Likelihood:                -560.34
# No. Observations:                 903   AIC:                             1125.
# Df Residuals:                     901   BIC:                             1134.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.7082      0.032     22.152      0.000         0.645     0.771
# Size           0.2784      0.019     15.002      0.000         0.242     0.315
# ==============================================================================
# Omnibus:                       24.647   Durbin-Watson:                   1.625
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               53.865
# Skew:                           0.054   Prob(JB):                     2.01e-12
# Kurtosis:                       4.192   Cond. No.                         4.70
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Part B - How is a linear regression model fitted?

# %%
np.linalg.inv(np.dot(X.T, X)).dot(X.T).dot(y)
# Out:
# array([ 0.15505177,  0.74972809])

# %% [markdown]
# ## Part C - How to check modeling assumptions?

# %% [markdown]
# ### `.plot_regress_exog()`

# %%
sm.graphics.plot_regress_exog(model, 'Size'); pass

# %% [markdown]
# ## Part D1 - How to check normality assumption?

# %% [markdown]
# ### Histogram of residuals

# %%
model = smf.ols(formula = 'SalePrice ~ Size', data = df).fit()

model.resid
# Out:
# ID
# 15063471     -0.151334
# 15063505      1.043660
# 15064044      0.496674
# 15064257     -0.099868
# 15064295     -0.055809
# 15064391     -0.164985
# 15064669      1.152707
# 15065032     -0.186621
# 15065140     -0.010621
# 15065727     -0.141891
# 15065810      0.801765
# 15065946      0.257440
# 15066036      1.330230
# 15066085     -0.066371
# 15066201      0.222544
# 15066281      0.583358
# 15066344      0.297277
# 15066608     -0.062898
# 15066839     -1.060812
# 15066959     -0.558559
# 15067302      0.027344
# 15067583     -0.130881
# 15067604     -0.210347
# 15067755     -0.163828
# 15067890      0.353775
# 15067896      0.661361
# 15068514     -0.185476
# 15068551     -0.054325
# 15068580     -0.166767
# 15068592     -0.097784
#                 ...
# 2100628935   -0.108556
# 2100646549    0.701553
# 2100651320    0.144587
# 2100695466    0.552339
# 2100784055   -0.984121
# 2100791455   -0.236621
# 2100850402    0.423596
# 2100901630    0.078367
# 2100902229    0.011904
# 2100992607    0.387420
# 2100994004   -0.309572
# 2101028916    1.101159
# 2101105851    0.175284
# 2101116542   -0.123262
# 2101147349   -0.097215
# 2101153805   -0.090537
# 2101156735   -0.062672
# 2101167573    0.233310
# 2101331127   -0.214670
# 2101505254    0.427300
# 2106229715   -0.140302
# 2108411930    0.604171
# 2114498518   -0.133903
# 2121221385   -1.115751
# 2121978635   -0.188283
# 2124214951   -0.391707
# 2126960082   -0.040591
# 2128308939   -0.362092
# 2131957929   -0.164985
# 2136213970   -0.133780
# dtype: float64

# %% [markdown]
# ### q-q plot of residuals against a normal distribution

# %%
model.resid.plot(kind = 'hist', bins = 250, figsize=(8,8))

# %% [markdown]
# > `line = 's'` shows a standardized line in which the expected order statistics are scaled by the standard deviation of the given sample and have the mean added to them

# %% [markdown]
# ## Part D2 - How to check normality assumption?

# %% [markdown]
# ### q-q plot of two normal distributions

# %%
sm.qqplot(model.resid, line = 's'); pass

# %%
normal_array = np.random.normal(0, 1, size = 100)
sm.qqplot(normal_array, line = '45'); pass

# %%
normal_array = np.random.normal(0, 1, size = 1000)
sm.qqplot(normal_array, line = '45'); pass

# %%
normal_array = np.random.normal(10, 1, size = 1000)
sm.qqplot(normal_array, line = '45'); pass

# %%
normal_array = np.random.normal(0, 10, size = 1000)
sm.qqplot(normal_array, line = '45'); pass

# %% [markdown]
# ## Part E - Inference and Fit

# %%
df = read_dataset()
scale_variables(df)

# %% [markdown]
# ### Effect of outliers on regression modeling - `SalePrice` as a function of `Size`

# %%
sns.lmplot('Size', 'SalePrice', df).set(xlim = (0, None), ylim = (0, None))

# %% [markdown]
# ### `SalePrice` as a function of `Size` after dropping the outliers

# %%
drop_outliers(df)
sns.lmplot('Size', 'SalePrice', df).set(xlim = (0, 14), ylim = (0, 35))
# Out:
# Dropping outliers
# - n (before) = 933
# - Q1         = 0.788 ($M)
# - Q2/Median  = 1.05 ($M)
# - Q3         = 1.43 ($M)
# - n (after)  = 915

# %% [markdown]
# ## Part F - $R^2$

# %%
df = read_dataset() # reload the dataset to get our outliers back...

scale_variables(df) # rescale the variables (use the function defined above)

# %% [markdown]
# ### `SalePrice` as a function of `Size`

# %%
model = smf.ols(formula = 'SalePrice ~ Size', data = df).fit()

model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.236
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     297.4
# Date:                Mon, 01 Aug 2016   Prob (F-statistic):           2.67e-58
# Time:                        21:03:06   Log-Likelihood:                -1687.9
# No. Observations:                 967   AIC:                             3380.
# Df Residuals:                     965   BIC:                             3390.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.1551      0.084      1.842      0.066        -0.010     0.320
# Size           0.7497      0.043     17.246      0.000         0.664     0.835
# ==============================================================================
# Omnibus:                     1842.865   Durbin-Watson:                   1.704
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):          3398350.943
# Skew:                          13.502   Prob(JB):                         0.00
# Kurtosis:                     292.162   Cond. No.                         4.40
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ### $R^2$

# %%
model.rsquared
# Out:
# 0.23559317159970783

# %% [markdown]
# ### Effects of outliers on $R^2$

# %%
print 'With outliers:'
print '- SalePrice ~     Size; R^2 =', smf.ols(formula = 'SalePrice ~ Size', data = df).fit().rsquared
print '- SalePrice ~ 0 + Size; R^2 =', smf.ols(formula = 'SalePrice ~ 0 + Size', data = df).fit().rsquared

print
drop_outliers(df) # drop outliers
print

print 'Without outliers:'
print '- SalePrice ~     Size; R^2 =', smf.ols(formula = 'SalePrice ~ Size', data = df).fit().rsquared
print '- SalePrice ~ 0 + Size; R^2 =', smf.ols(formula = 'SalePrice ~ 0 + Size', data = df).fit().rsquared
# Out:
# With outliers:
# - SalePrice ~     Size; R^2 = 0.2355931716
# - SalePrice ~ 0 + Size; R^2 = 0.565060681491
#
# Dropping outliers
# - n (before) = 1000
# - Q1         = 0.8 ($M)
# - Q2/Median  = 1.1 ($M)
# - Q3         = 1.5325 ($M)
# - n (after)  = 933
#
# Without outliers:
# - SalePrice ~     Size; R^2 = 0.199855535471
# - SalePrice ~ 0 + Size; R^2 = 0.796063918194

# %% [markdown]
# ## Part G - Multiple Linear Regression

# %%
df = read_dataset() # reload the dataset to get our outliers back...

scale_variables(df) # scaling variables (function defined above)

# %% [markdown]
# ### `SalePrice` as a function of `Size` and `BedCount`

# %%
model = smf.ols(formula = 'SalePrice ~ Size + BedCount', data = df).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              SalePrice   R-squared:                       0.554
# Model:                            OLS   Adj. R-squared:                  0.553
# Method:                 Least Squares   F-statistic:                     506.9
# Date:                Mon, 01 Aug 2016   Prob (F-statistic):          8.01e-144
# Time:                        21:08:40   Log-Likelihood:                -1026.2
# No. Observations:                 819   AIC:                             2058.
# Df Residuals:                     816   BIC:                             2073.
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      0.1968      0.068      2.883      0.004         0.063     0.331
# Size           1.2470      0.045     27.531      0.000         1.158     1.336
# BedCount      -0.3022      0.034     -8.839      0.000        -0.369    -0.235
# ==============================================================================
# Omnibus:                      626.095   Durbin-Watson:                   1.584
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            34896.976
# Skew:                           2.908   Prob(JB):                         0.00
# Kurtosis:                      34.445   Cond. No.                         8.35
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# ## Part H - Multicollinearity

# %% [markdown]
# ### Transforming Variables (cont.)

# %% [markdown]
# > #### Activity | Create new variables `SizeLog` and `LotSizeLog` that represent the log of `Size` and `LotSize`.  Repeat using square root, cube root, square, and cube

# %%
df[ ['SizeLog', 'LotSizeLog'] ] = df[ ['Size', 'LotSize'] ].apply(np.log10)

# %%
df
# Out:
#                                                  Address DateOfSale  \
# ID
# 15063471       55 Vandewater St APT 9, San Francisco, CA    12/4/15
# 15063505             740 Francisco St, San Francisco, CA   11/30/15
# 15063609             819 Francisco St, San Francisco, CA   11/12/15
# 15064044        199 Chestnut St APT 5, San Francisco, CA   12/11/15
# 15064257      111 Chestnut St APT 403, San Francisco, CA    1/15/16
# 15064295      111 Chestnut St APT 702, San Francisco, CA   12/17/15
# 15064391       1821 Grant Ave APT 101, San Francisco, CA   12/15/15
# 15064536          2300 Leavenworth St, San Francisco, CA    12/4/15
# 15064640         1047-1049 Lombard St, San Francisco, CA    1/14/16
# 15064669          1055 Lombard St # C, San Francisco, CA   12/31/15
# 15065032      101 Lombard St APT 116E, San Francisco, CA    12/7/15
# 15065140     1407 Montgomery St APT 2, San Francisco, CA    1/28/16
# 15065727     1360 Montgomery St APT 1, San Francisco, CA   11/16/15
# 15065810          1327-1329 Kearny St, San Francisco, CA   11/25/15
# 15065946       44 Macondray Ln APT 2E, San Francisco, CA   11/30/15
# 15066001        1070 Green St APT 201, San Francisco, CA   11/18/15
# 15066036       1070 Green St APT 1402, San Francisco, CA   12/31/15
# 15066085    1907 Leavenworth St APT 8, San Francisco, CA   11/12/15
# 15066201          1101 Green St # 303, San Francisco, CA   11/16/15
# 15066281                1807 Jones St, San Francisco, CA   12/15/15
# 15066344         999 Green St APT 905, San Francisco, CA   12/10/15
# 15066608       455 Vallejo St APT 111, San Francisco, CA   12/16/15
# 15066839         1163-1165 Vallejo St, San Francisco, CA    12/1/15
# 15066959             1300 Pacific Ave, San Francisco, CA    1/14/16
# 15067302               948 Jackson St, San Francisco, CA   11/13/15
# 15067583       946 Stockton St APT 6B, San Francisco, CA   12/18/15
# 15067604       946 Stockton St APT 9E, San Francisco, CA    12/2/15
# 15067755         1250 Clay St APT 306, San Francisco, CA    1/10/16
# 15067890        1250 Jones St APT 503, San Francisco, CA    12/4/15
# 15067896        1250 Jones St APT 802, San Francisco, CA   12/15/15
# ...                                                  ...        ...
# 2100992607               2137 Pine St, San Francisco, CA    1/15/16
# 2100994004              409 Miguel St, San Francisco, CA    12/9/15
# 2101028916            251 Missouri St, San Francisco, CA   12/17/15
# 2101094207            1650 Florida St, San Francisco, CA   11/29/15
# 2101105851          41 Collingwood St, San Francisco, CA   12/10/15
# 2101116542             2753 Bryant St, San Francisco, CA    1/14/16
# 2101147349            244 Precita Ave, San Francisco, CA   11/26/15
# 2101153805                6 Rossi Ave, San Francisco, CA    12/2/15
# 2101156735            333 Potrero Ave, San Francisco, CA     1/5/16
# 2101167573              1340 Union St, San Francisco, CA    1/25/16
# 2101169168            688 Douglass St, San Francisco, CA   11/10/15
# 2101175813              414 Linden St, San Francisco, CA   12/13/15
# 2101331127      1408 31st Ave APT 303, San Francisco, CA   12/28/15
# 2101505254               333 Beale St, San Francisco, CA    12/3/15
# 2101588805             82 Alvarado St, San Francisco, CA   11/19/15
# 2101807538         2619 Sacramento St, San Francisco, CA    12/2/15
# 2102385068            129 Central Ave, San Francisco, CA    12/1/15
# 2102906272              444 Linden St, San Francisco, CA   12/14/15
# 2106229715              2595 38th Ave, San Francisco, CA    1/19/16
# 2108411930               3500 19th St, San Francisco, CA   12/29/15
# 2108546010      1738 Lombard St APT 4, San Francisco, CA    1/14/16
# 2114498518    201 Sansome St UNIT 501, San Francisco, CA    1/26/16
# 2121221385              925 Larkin St, San Francisco, CA   11/30/15
# 2121978635     829 Folsom St UNIT 906, San Francisco, CA    12/6/15
# 2122992200             129 Octavia St, San Francisco, CA   11/20/15
# 2124214951         412 Green St APT A, San Francisco, CA    1/15/16
# 2126960082       355 1st St UNIT 1905, San Francisco, CA   11/20/15
# 2128308939          33 Santa Cruz Ave, San Francisco, CA   12/10/15
# 2131957929             1821 Grant Ave, San Francisco, CA   12/15/15
# 2136213970              1200 Gough St, San Francisco, CA    1/10/16
#
#             SalePrice  IsAStudio  BedCount     ...       Size  LotSize  \
# ID                                             ...
# 15063471       0.7100        0.0       1.0     ...      0.550      NaN
# 15063505       2.1500        0.0       NaN     ...      1.430    2.435
# 15063609       5.6000        0.0       2.0     ...      2.040    3.920
# 15064044       1.5000        0.0       1.0     ...      1.060      NaN
# 15064257       0.9700        0.0       2.0     ...      1.299      NaN
# 15064295       0.9400        0.0       2.0     ...      1.033      NaN
# 15064391       0.8350        0.0       1.0     ...      1.048      NaN
# 15064536       2.8300        0.0       3.0     ...      2.115    1.271
# 15064640       4.0500        1.0       NaN     ...      4.102    3.049
# 15064669       2.1900        0.0       2.0     ...      1.182      NaN
# 15065032       0.8000        0.0       1.0     ...      1.000      NaN
# 15065140       0.9760        0.0       1.0     ...      1.000      NaN
# 15065727       0.7200        0.0       1.0     ...      0.552      NaN
# 15065810       2.2500        0.0       NaN     ...      2.658    1.600
# 15065946       1.2900        0.0       2.0     ...      1.165      NaN
# 15066001       2.9000        0.0       2.0     ...      1.465      NaN
# 15066036       2.6000        0.0       3.0     ...      2.017      NaN
# 15066085       0.9080        0.0       2.0     ...      0.956      NaN
# 15066201       1.2100        0.0       2.0     ...      1.003      NaN
# 15066281       1.7000        0.0       2.0     ...      1.467    3.023
# 15066344       1.2800        0.0       1.0     ...      0.986      NaN
# 15066608       0.8750        0.0       1.0     ...      0.825      NaN
# 15066839       0.3000        0.0       NaN     ...      2.344    1.376
# 15066959       0.4250        1.0       NaN     ...      0.989      NaN
# 15067302       1.9500        0.0       NaN     ...      4.362    1.459
# 15067583       0.7750        0.0       NaN     ...      0.710      NaN
# 15067604       0.7050        0.0       2.0     ...      0.744      NaN
# 15067755       0.6950        0.0       1.0     ...      0.541      NaN
# 15067890       1.4100        0.0       1.0     ...      1.250      NaN
# 15067896       1.6800        0.0       1.0     ...      1.115      NaN
# ...               ...        ...       ...     ...        ...      ...
# 2100992607     1.5500        0.0       4.0     ...      1.632      NaN
# 2100994004     0.5100        0.0       1.0     ...      0.400      NaN
# 2101028916     2.4500        0.0       4.0     ...      2.301      NaN
# 2101094207     0.9700        0.0       3.0     ...        NaN      NaN
# 2101105851     1.3000        0.0       3.0     ...      1.496      NaN
# 2101116542     1.7000        0.0       9.0     ...      4.005      NaN
# 2101147349     0.7850        0.0       1.0     ...      0.625      NaN
# 2101153805     1.1500        0.0       3.0     ...      1.912      NaN
# 2101156735     1.1400        1.0       NaN     ...      1.776    3.746
# 2101167573     1.2500        0.0       2.0     ...      1.108      NaN
# 2101169168     3.1500        1.0       NaN     ...      3.500    2.495
# 2101175813     0.8350        0.0       1.0     ...        NaN      NaN
# 2101331127     0.8900        0.0       2.0     ...      1.424      NaN
# 2101505254     1.4000        0.0       1.0     ...      0.950      NaN
# 2101588805     0.7500        0.0       2.0     ...        NaN      NaN
# 2101807538     2.9000        1.0       NaN     ...        NaN    2.038
# 2102385068     1.8000        0.0       3.0     ...        NaN      NaN
# 2102906272     0.0058        NaN       NaN     ...        NaN      NaN
# 2106229715     1.2400        0.0       3.0     ...      2.414    1.306
# 2108411930     1.7300        0.0       2.0     ...      1.500      NaN
# 2108546010     1.4000        0.0       2.0     ...        NaN      NaN
# 2114498518     0.7575        0.0       1.0     ...      0.658      NaN
# 2121221385     1.4300        0.0       NaN     ...      6.600      NaN
# 2121978635     0.6750        0.0       1.0     ...      0.557      NaN
# 2122992200     2.7500        1.0       NaN     ...      3.655      NaN
# 2124214951     0.3900        1.0       NaN     ...      0.264      NaN
# 2126960082     0.8600        0.0       1.0     ...      0.691      NaN
# 2128308939     0.8300        0.0       3.0     ...      1.738    2.299
# 2131957929     0.8350        0.0       2.0     ...      1.048      NaN
# 2136213970     0.8250        0.0       1.0     ...      0.900      NaN
#
#             BuiltInYear   SizeLog  LotSizeLog
# ID
# 15063471         1980.0 -0.259637         NaN
# 15063505         1948.0  0.155336    0.386499
# 15063609         1976.0  0.309630    0.593286
# 15064044         1930.0  0.025306         NaN
# 15064257         1993.0  0.113609         NaN
# 15064295         1993.0  0.014100         NaN
# 15064391         1975.0  0.020361         NaN
# 15064536         1913.0  0.325310    0.104146
# 15064640         1948.0  0.612996    0.484157
# 15064669         1986.0  0.072617         NaN
# 15065032         1983.0  0.000000         NaN
# 15065140         1870.0  0.000000         NaN
# 15065727         1937.0 -0.258061         NaN
# 15065810         1906.0  0.424555    0.204120
# 15065946         1980.0  0.066326         NaN
# 15066001         1963.0  0.165838         NaN
# 15066036         1963.0  0.304706         NaN
# 15066085         1907.0 -0.019542         NaN
# 15066201         1930.0  0.001301         NaN
# 15066281         1922.0  0.166430    0.480438
# 15066344         1964.0 -0.006123         NaN
# 15066608         1973.0 -0.083546         NaN
# 15066839         1913.0  0.369958    0.138618
# 15066959         1910.0 -0.004804         NaN
# 15067302         1908.0  0.639686    0.164055
# 15067583         1970.0 -0.148742         NaN
# 15067604         1970.0 -0.128427         NaN
# 15067755         1950.0 -0.266803         NaN
# 15067890         1929.0  0.096910         NaN
# 15067896         1929.0  0.047275         NaN
# ...                 ...       ...         ...
# 2100992607          NaN  0.212720         NaN
# 2100994004          NaN -0.397940         NaN
# 2101028916       1900.0  0.361917         NaN
# 2101094207       1904.0       NaN         NaN
# 2101105851       1908.0  0.174932         NaN
# 2101116542       1900.0  0.602603         NaN
# 2101147349       1908.0 -0.204120         NaN
# 2101153805       1941.0  0.281488         NaN
# 2101156735       1905.0  0.249443    0.573568
# 2101167573       1951.0  0.044540         NaN
# 2101169168       1908.0  0.544068    0.397071
# 2101175813       1909.0       NaN         NaN
# 2101331127       2008.0  0.153510         NaN
# 2101505254       2015.0 -0.022276         NaN
# 2101588805          NaN       NaN         NaN
# 2101807538       1900.0       NaN    0.309204
# 2102385068       1905.0       NaN         NaN
# 2102906272          NaN       NaN         NaN
# 2106229715       1943.0  0.382737    0.115943
# 2108411930       2013.0  0.176091         NaN
# 2108546010       2004.0       NaN         NaN
# 2114498518       1909.0 -0.181774         NaN
# 2121221385       1907.0  0.819544         NaN
# 2121978635       2010.0 -0.254145         NaN
# 2122992200       1883.0  0.562887         NaN
# 2124214951       2012.0 -0.578396         NaN
# 2126960082       2004.0 -0.160522         NaN
# 2128308939       1976.0  0.240050    0.361539
# 2131957929       1975.0  0.020361         NaN
# 2136213970       1966.0 -0.045757         NaN
#
# [1000 rows x 11 columns]

# %% [markdown]
# ### Multicollinearity

# %% [markdown]
# > #### Activity | Show the correlation between the different engineered features of  `Size`

# %%
df[ ['Size', 'SizeLog', 'SizeSqrt', 'SizeCbrt', 'SizeSquare', 'SizeCube'] ].corr()

# %% [markdown]
# #### `SalePrice` as a function of `Size` and its other engineered features

# %%
# TODO

# %% [markdown]
# > #### Activity | What happened?

# %% [markdown]
# ## Part I - Adjusted $R^2$

# %%
formula = 'SalePrice ~ 0 + IsAStudio + BedCount + BathCount + Size + LotSize'

model = smf.ols(formula = formula, data = df).fit()

print 'R^2 =', model.rsquared, '(original model)'
# Out:
# R^2 = 0.780097143233 (original model)

# %% [markdown]
# Let's now add some artificial noise.

# %%
x_df = pd.DataFrame(index = df.index)

for i in range(100):
    x = 'X{}'.format(i)
    x_df[x] = np.random.random(df.shape[0])

formula = 'SalePrice ~ 0 + IsAStudio + BedCount + BathCount + Size + LotSize + BuiltInYear + '
formula += ' + '.join(x_df.columns.values)

# %%
formula
# Out:
# 'SalePrice ~ 0 + IsAStudio + BedCount + BathCount + Size + LotSize + BuiltInYear + X0 + X1 + X2 + X3 + X4 + X5 + X6 + X7 + X8 + X9 + X10 + X11 + X12 + X13 + X14 + X15 + X16 + X17 + X18 + X19 + X20 + X21 + X22 + X23 + X24 + X25 + X26 + X27 + X28 + X29 + X30 + X31 + X32 + X33 + X34 + X35 + X36 + X37 + X38 + X39 + X40 + X41 + X42 + X43 + X44 + X45 + X46 + X47 + X48 + X49 + X50 + X51 + X52 + X53 + X54 + X55 + X56 + X57 + X58 + X59 + X60 + X61 + X62 + X63 + X64 + X65 + X66 + X67 + X68 + X69 + X70 + X71 + X72 + X73 + X74 + X75 + X76 + X77 + X78 + X79 + X80 + X81 + X82 + X83 + X84 + X85 + X86 + X87 + X88 + X89 + X90 + X91 + X92 + X93 + X94 + X95 + X96 + X97 + X98 + X99'

# %%
x_df = x_df.join(df)

x_model = smf.ols(formula = formula, data = x_df).fit()

# %%
print 'Model with artificial noise:'
print '-          R^2 =', x_model.rsquared
print '- Adjusted R^2 =', x_model.rsquared_adj
# Out:
# Model with artificial noise:
# -          R^2 = 0.831446585414
# - Adjusted R^2 = 0.77682279365
